# %% [markdown]
# <a href="https://colab.research.google.com/github/kitsii/fuzzy-kits/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input('Введите ваш возраст:'))
if age < 18:
 print('детский')
elif 18 <= age <= 29:
  print('молодой')
elif 30 <= age <= 59:
  print('взрослый')
else:
  print('пожилой')
# Out:
# Введите ваш возраст:18
# молодой
